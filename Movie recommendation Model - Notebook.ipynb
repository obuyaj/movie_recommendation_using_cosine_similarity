# %% [markdown]
# # Movie Recommendation Model Built Using Cosine Similarity

# %% [markdown]
# This is a recommendation model used to made using Cosine Similarity ALgorithm.

# %% [markdown]
# ## Import Libraries and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import model_selection
import warnings
warnings.filterwarnings('ignore')

import plotly_express as px
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_csv('netflix_movies_datatset.csv')

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# ## Understanding the features

# %%
print("The data has {} rows and {} columns".format(data.shape[0], data.shape[1]))
# Out:
# The data has 7787 rows and 12 columns

# %% [markdown]
# Next we need to check the types of data contained

# %%
for i in data.columns:
    print(i, ":", data.dtypes[i])
# Out:
# show_id : object
# type : object
# title : object
# director : object
# cast : object
# country : object
# date_added : object
# release_year : int64
# rating : object
# duration : object
# listed_in : object
# description : object

# %% [markdown]
# All the features are object variables except release_year.
#
# Convert date_added column to date

# %%
data['date_added'] = pd.to_datetime(data['date_added'])
print(data.date_added.dtypes)
# Out:
# datetime64[ns]

# %% [markdown]
# ### Duplicate Rows

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# This shows that the data has not duplicated rows. However, what if we ignore the movie_id column which is meant to make the rows unique? It could be possible to have duplicate content. Let's explore

# %%
data_d0 = data.iloc[:, 1:] #filters the show_id column
data_d0[data_d0.duplicated()]
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data[data["cast"].duplicated()][data.cast.notna()] # Filtering data with duplicate casts and excluding null values
# Out:
#      show_id     type                                       title  \
# 139     s140  TV Show         72 Dangerous Animals: Latin America
# 387     s388    Movie                   Ali Wong: Hard Knock Wife
# 483     s484    Movie            Amy Schumer: The Leather Special
# 510     s511    Movie                                 Andhakaaram
# 525     s526    Movie            Angu Vaikuntapurathu (Malayalam)
# ...      ...      ...                                         ...
# 7428   s7429    Movie                          Vir Das: Losing It
# 7429   s7430    Movie  Vir Das: Outside In - The Lockdown Special
# 7522   s7523  TV Show                  Weird Wonders of the World
# 7604   s7605    Movie                Whitney Cummings: Money Shot
# 7716   s7717    Movie                        Yoko and His Friends
#
#                 director                                               cast  \
# 139                  NaN                                       Bob Brisbane
# 387            Jay Karas                                           Ali Wong
# 483          Amy Schumer                                        Amy Schumer
# 510         V Vignarajan  Vinoth Kishan, Arjun Das, Pooja Ramachandran, ...
# 525   Trivikram Srinivas  Allu Arjun, Pooja Hegde, Tabu, Sushanth, Nivet...
# ...                  ...                                                ...
# 7428        Marcus Raboy                                            Vir Das
# 7429             Vir Das                                            Vir Das
# 7522                 NaN                                      Chris Packham
# 7604    John Fortenberry                                   Whitney Cummings
# 7716                 NaN  Eileen Stevens, Alyson Leigh Rosenfeld, Sarah ...
#
#                        country date_added  release_year rating   duration  \
# 139   Australia, United States 2017-12-22          2017  TV-14   1 Season
# 387              United States 2018-05-13          2018  TV-MA     64 min
# 483              United States 2017-03-07          2017  TV-MA     57 min
# 510                      India 2020-11-24          2020  TV-14    171 min
# 525                        NaN 2020-03-05          2020  TV-14    162 min
# ...                        ...        ...           ...    ...        ...
# 7428             United States 2018-12-11          2018  TV-MA     68 min
# 7429                     India 2020-12-16          2020  TV-MA     50 min
# 7522            United Kingdom 2017-03-31          2016  TV-PG  2 Seasons
# 7604             United States 2019-01-01          2010  TV-MA     48 min
# 7716             Russia, Spain 2018-06-23          2015   TV-Y     78 min
#
#                                               listed_in  \
# 139   Docuseries, International TV Shows, Science & ...
# 387                                     Stand-Up Comedy
# 483                                     Stand-Up Comedy
# 510      Horror Movies, International Movies, Thrillers
# 525                Action & Adventure, Comedies, Dramas
# ...                                                 ...
# 7428                                    Stand-Up Comedy
# 7429                                    Stand-Up Comedy
# 7522  British TV Shows, Docuseries, Science & Nature TV
# 7604                                    Stand-Up Comedy
# 7716                           Children & Family Movies
#
#                                             description
# 139   Powerful cats, indestructible arachnids and fl...
# 387   Two years after the hit "Baby Cobra," Ali Wong...
# 483   Comic sensation Amy Schumer riffs on sex, dati...
# 510   As a blind librarian, dispirited cricketer and...
# 525   After growing up enduring criticism from his f...
# ...                                                 ...
# 7428  The world's got a lot of problems, but Vir Das...
# 7429  Stage banter takes on a different — deeper — m...
# 7522  From animal oddities and bizarre science to me...
# 7604  Comedy Central roast veteran Whitney Cummings ...
# 7716  Vik meets new friends in a new city, where the...
#
# [238 rows x 12 columns]

# %%
data.cast.loc[510] # display the details of row 7716 that has duplicate content
# Out:
# 'Vinoth Kishan, Arjun Das, Pooja Ramachandran, Kumar Natarajan, Misha Ghoshal, Arul Vincent, Chenthu Mohan, Pradeep Kalipurayath'

# %%
data[data['cast'] == data.cast.loc[510]] #comparing two rows with duplicate casts
# Out:
#     show_id   type         title      director  \
# 509    s510  Movie  Andhaghaaram  V Vignarajan
# 510    s511  Movie   Andhakaaram  V Vignarajan
#
#                                                   cast country date_added  \
# 509  Vinoth Kishan, Arjun Das, Pooja Ramachandran, ...     NaN 2020-11-24
# 510  Vinoth Kishan, Arjun Das, Pooja Ramachandran, ...   India 2020-11-24
#
#      release_year rating duration  \
# 509          2020  TV-14  171 min
# 510          2020  TV-14  171 min
#
#                                           listed_in  \
# 509  Horror Movies, International Movies, Thrillers
# 510  Horror Movies, International Movies, Thrillers
#
#                                            description
# 509  As a blind librarian, dispirited cricketer and...
# 510  As a blind librarian, dispirited cricketer and...

# %%
data.cast.loc[7716] # display the details of row 7716 that has duplicate content
# Out:
# 'Eileen Stevens, Alyson Leigh Rosenfeld, Sarah Natochenny, H.D. Quinn'

# %%
data[data['cast'] == 'Eileen Stevens, Alyson Leigh Rosenfeld, Sarah Natochenny, H.D. Quinn'] #comparing two rows with duplicate casts
# Out:
#      show_id     type                 title director  \
# 7715   s7716  TV Show                  Yoko      NaN
# 7716   s7717    Movie  Yoko and His Friends      NaN
#
#                                                    cast        country  \
# 7715  Eileen Stevens, Alyson Leigh Rosenfeld, Sarah ...            NaN
# 7716  Eileen Stevens, Alyson Leigh Rosenfeld, Sarah ...  Russia, Spain
#
#      date_added  release_year rating  duration                 listed_in  \
# 7715 2018-06-23          2016   TV-Y  1 Season                  Kids' TV
# 7716 2018-06-23          2015   TV-Y    78 min  Children & Family Movies
#
#                                             description
# 7715  Friends Mai, Oto and Vik's games at the park b...
# 7716  Vik meets new friends in a new city, where the...

# %% [markdown]
# Comparison of two different sets of duplicate values show the possibility of having duplicate and non-duplicate rows if the casts are identical. How about the description column?

# %%
data[data["description"].duplicated()][data.description.notna()] # Filtering data with duplicate casts and excluding null values
# 4839            NaN 2019-04-07          2019  TV-14   170 min
# 5397          India 2019-04-08          2018  TV-14   131 min
# 5510          India 2020-06-26          2019  TV-MA   111 min
# 5511            NaN 2020-06-26          2019  TV-14   116 min
# 5699  United States 2019-01-09          2018  PG-13   135 min
# 6039          India 2020-06-26          2019  TV-14   135 min
# 6487  United States 2019-01-30          2018     PG   118 min
# 6721         France 2020-01-14          2018   TV-Y  1 Season
# 7129          India 2020-02-01          1999   TV-G   176 min
#
#                                               listed_in  \
# 510      Horror Movies, International Movies, Thrillers
# 525                Action & Adventure, Comedies, Dramas
# 1287   Comedies, International Movies, Music & Musicals
# 1377                                           Kids' TV
# 1486            Dramas, International Movies, Thrillers
# 2343     Horror Movies, International Movies, Thrillers
# 4441                    International Movies, Thrillers
# 4594   Comedies, International Movies, Music & Musicals
# 4595   Comedies, International Movies, Music & Musicals
# 4839               Action & Adventure, Comedies, Dramas
# 5397     Dramas, International Movies, Music & Musicals
# 5510      Dramas, International Movies, Romantic Movies
# 5511      Dramas, International Movies, Romantic Movies
# 5699  Action & Adventure, Children & Family Movies, ...
# 6039                       Dramas, International Movies
# 6487                 Children & Family Movies, Comedies
# 6721                                           Kids' TV
# 7129     Dramas, International Movies, Music & Musicals
#
#                                             description
# 510   As a blind librarian, dispirited cricketer and...
# 525   After growing up enduring criticism from his f...
# 1287  When pretty new neighbor Seema falls for their...
# 1377  This educational series for tiny tots features...
# 1486  Secrets bubble to the surface after a sensual ...
# 2343  As a series of murders hit close to home, a vi...
# 4441  As a woman scours Hyderabad for her missing hu...
# 4594  A surly septuagenarian gets another chance at ...
# 4595  A surly septuagenarian gets another chance at ...
# 4839  An affable, newly appointed college warden pro...
# 5397  An aspiring musician battles age-old caste div...
# 5510  Multiple women report their husbands as missin...
# 5511  Multiple women report their husbands as missin...
# 5699  A young Han Solo tries to settle an old score ...
# 6039  From controversial cartoonist to powerful Mumb...
# 6487  When Elastigirl gets recruited for a high-prof...
# 6721  Two quirky cats, Ollie and Moon, and their fri...
# 7129  A scheming matriarch plots to cut off her disa...

# %% [markdown]
# There are 18 rows with duplicate rows. It is very difficult to have 2 movies to have identical description, and thus these are duplicate values. Details on 3 possible duplicates are compared to establish similarity.

# %%
data[data.description == data.description.loc[510]] #comparing two rows with duplicate casts
# Out:
#     show_id   type         title      director  \
# 509    s510  Movie  Andhaghaaram  V Vignarajan
# 510    s511  Movie   Andhakaaram  V Vignarajan
#
#                                                   cast country date_added  \
# 509  Vinoth Kishan, Arjun Das, Pooja Ramachandran, ...     NaN 2020-11-24
# 510  Vinoth Kishan, Arjun Das, Pooja Ramachandran, ...   India 2020-11-24
#
#      release_year rating duration  \
# 509          2020  TV-14  171 min
# 510          2020  TV-14  171 min
#
#                                           listed_in  \
# 509  Horror Movies, International Movies, Thrillers
# 510  Horror Movies, International Movies, Thrillers
#
#                                            description
# 509  As a blind librarian, dispirited cricketer and...
# 510  As a blind librarian, dispirited cricketer and...

# %%
data[data.description == data.description.loc[1287]] #comparing two rows with duplicate casts
# Out:
#      show_id   type            title      director  \
# 1286   s1287  Movie  Chashme Baddoor  David Dhawan
# 1287   s1288  Movie  Chashme Buddoor  David Dhawan
#
#                                                    cast country date_added  \
# 1286  Rishi Kapoor, Ali Zafar, Taapsee Pannu, Siddha...   India 2020-07-05
# 1287  Ali Zafar, Siddharth, Divyendu Sharma, Tapsee ...   India 2017-05-01
#
#       release_year rating duration  \
# 1286          2013  TV-14  121 min
# 1287          2013  TV-PG  121 min
#
#                                              listed_in  \
# 1286  Comedies, International Movies, Music & Musicals
# 1287  Comedies, International Movies, Music & Musicals
#
#                                             description
# 1286  When pretty new neighbor Seema falls for their...
# 1287  When pretty new neighbor Seema falls for their...

# %%
data[data.description == data.description.loc[4594]]
# Out:
#      show_id   type                 title             director  \
# 4593   s4594  Movie              Oh! Baby  B. V. Nandini Reddy
# 4594   s4595  Movie  Oh! Baby (Malayalam)  B. V. Nandini Reddy
# 4595   s4596  Movie      Oh! Baby (Tamil)  B. V. Nandini Reddy
#
#                                                    cast country date_added  \
# 4593  Samantha Ruth Prabhu, Lakshmi, Rajendraprasad,...   India 2019-09-14
# 4594  Samantha Ruth Prabhu, Lakshmi, Rajendraprasad,...     NaN 2019-09-25
# 4595  Samantha Ruth Prabhu, Lakshmi, Rajendraprasad,...     NaN 2019-09-25
#
#       release_year rating duration  \
# 4593          2019  TV-14  157 min
# 4594          2019  TV-14  146 min
# 4595          2019  TV-14  146 min
#
#                                              listed_in  \
# 4593  Comedies, International Movies, Music & Musicals
# 4594  Comedies, International Movies, Music & Musicals
# 4595  Comedies, International Movies, Music & Musicals
#
#                                             description
# 4593  A surly septuagenarian gets another chance at ...
# 4594  A surly septuagenarian gets another chance at ...
# 4595  A surly septuagenarian gets another chance at ...

# %% [markdown]
# A close look at 3 movies with duplicate description shows that they are actually duplicate movies. Row 4594 is the same movie but in different language. These can therefore be removed as duplicates.

# %%
data0 = data.drop_duplicates(subset=['description'],keep="first")
data0
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7785                NaN                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                                NaN
#
#                                                 country date_added  \
# 0                                                Brazil 2020-08-14
# 1                                                Mexico 2016-12-23
# 2                                             Singapore 2018-12-20
# 3                                         United States 2017-11-16
# 4                                         United States 2020-01-01
# ...                                                 ...        ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar... 2020-10-19
# 7783                                              India 2019-03-02
# 7784                                                NaN 2020-09-25
# 7785                                          Australia 2020-10-31
# 7786              United Kingdom, Canada, United States 2020-03-01
#
#       release_year rating   duration  \
# 0             2020  TV-MA  4 Seasons
# 1             2016  TV-MA     93 min
# 2             2011      R     78 min
# 3             2009  PG-13     80 min
# 4             2008  PG-13    123 min
# ...            ...    ...        ...
# 7782          2005  TV-MA     99 min
# 7783          2015  TV-14    111 min
# 7784          2019  TV-MA     44 min
# 7785          2019  TV-PG   1 Season
# 7786          2019  TV-MA     90 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [7769 rows x 12 columns]

# %% [markdown]
# Data0 has no duplicate values.

# %%
len(data0[data0["description"].duplicated()][data0.description.notna()])
# Out:
# 0

# %% [markdown]
# ### Missing Values

# %% [markdown]
# Next, we look for percentage of empty rows in each feature. This will inform the variables that can be considered in model building.
#
# Features with more than 5% empty rows may not be suitable for model building

# %%
for i in data0.columns:
    print(i, " column has {}% empty rows".format(int(data0[i].isnull().sum()/len(data0)*100)))
# Out:
# show_id  column has 0% empty rows
# type  column has 0% empty rows
# title  column has 0% empty rows
# director  column has 30% empty rows
# cast  column has 9% empty rows
# country  column has 6% empty rows
# date_added  column has 0% empty rows
# release_year  column has 0% empty rows
# rating  column has 0% empty rows
# duration  column has 0% empty rows
# listed_in  column has 0% empty rows
# description  column has 0% empty rows

# %% [markdown]
# The features: director, cast and country have more than 5% empty values, and may not suitable in model building.
#
# Next we look at how many distinct values exist in a row. This informs more on the features that can be used in model building. The fewer the unique values the unique values the more suitable a feature is. From the outputs below and above, the following features are good candidates: type, rating and listed_in.

# %%
data0.nunique()
# Out:
# show_id         7769
# type               2
# title           7769
# director        4049
# cast            6828
# country          680
# date_added      1512
# release_year      73
# rating            14
# duration         216
# listed_in        492
# description     7769
# dtype: int64

# %% [markdown]
# Next we look at the frequencies of the modal values in each feature. This gives insight to each feature's modal frequencies.

# %%
data0.describe(include='all')
# Out:
#        show_id   type title                director                cast  \
# count     7769   7769  7769                    5384                7054
# unique    7769      2  7769                    4049                6828
# top         s1  Movie    3%  Raúl Campos, Jan Suter  David Attenborough
# freq         1   5361     1                      18                  18
# first      NaN    NaN   NaN                     NaN                 NaN
# last       NaN    NaN   NaN                     NaN                 NaN
# mean       NaN    NaN   NaN                     NaN                 NaN
# std        NaN    NaN   NaN                     NaN                 NaN
# min        NaN    NaN   NaN                     NaN                 NaN
# 25%        NaN    NaN   NaN                     NaN                 NaN
# 50%        NaN    NaN   NaN                     NaN                 NaN
# 75%        NaN    NaN   NaN                     NaN                 NaN
# max        NaN    NaN   NaN                     NaN                 NaN
#
#               country           date_added  release_year rating  duration  \
# count            7268                 7759   7769.000000   7762      7769
# unique            680                 1512           NaN     14       216
# top     United States  2020-01-01 00:00:00           NaN  TV-MA  1 Season
# freq             2553                  119           NaN   2860      1606
# first             NaN  2008-01-01 00:00:00           NaN    NaN       NaN
# last              NaN  2021-01-16 00:00:00           NaN    NaN       NaN
# mean              NaN                  NaN   2013.925730    NaN       NaN
# std               NaN                  NaN      8.763353    NaN       NaN
# min               NaN                  NaN   1925.000000    NaN       NaN
# 25%               NaN                  NaN   2013.000000    NaN       NaN
# 50%               NaN                  NaN   2017.000000    NaN       NaN
# 75%               NaN                  NaN   2018.000000    NaN       NaN
# max               NaN                  NaN   2021.000000    NaN       NaN
#
#             listed_in                                        description
# count            7769                                               7769
# unique            492                                               7769
# top     Documentaries  In a future where the elite inhabit an island ...
# freq              334                                                  1
# first             NaN                                                NaN
# last              NaN                                                NaN
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN

# %% [markdown]
# ### Text EDA

# %% [markdown]
# To better understand how data is captured under various features, we group the desired features and observe how the datapoints are captured.

# %%
data0.groupby(data0.type)['show_id'].count()
# Out:
# type
# Movie      5361
# TV Show    2408
# Name: show_id, dtype: int64

# %%
data0.groupby(data0.rating)['show_id'].count()
# Out:
# rating
# G             39
# NC-17          3
# NR            84
# PG           246
# PG-13        385
# R            665
# TV-14       1922
# TV-G         193
# TV-MA       2860
# TV-PG        805
# TV-Y         278
# TV-Y7        271
# TV-Y7-FV       6
# UR             5
# Name: show_id, dtype: int64

# %%
data0.groupby(data0.country)['show_id'].count()
# Out:
# country
# Argentina                                              50
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        1
# Argentina, Chile, Peru                                  1
# Argentina, France                                       1
#                                                        ..
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 5
# West Germany                                            1
# Zimbabwe                                                1
# Name: show_id, Length: 680, dtype: int64

# %%
data0.groupby(data0.listed_in)['show_id'].count()
# Out:
# listed_in
# Action & Adventure                                              99
# Action & Adventure, Anime Features, Children & Family Movies     3
# Action & Adventure, Anime Features, Classic Movies               1
# Action & Adventure, Anime Features, Horror Movies                1
# Action & Adventure, Anime Features, International Movies        28
#                                                                 ..
# TV Horror, TV Mysteries, Teen TV Shows                           1
# TV Horror, Teen TV Shows                                         1
# TV Sci-Fi & Fantasy, TV Thrillers                                1
# TV Shows                                                        12
# Thrillers                                                       49
# Name: show_id, Length: 492, dtype: int64

# %% [markdown]
# ## Text Pre-Processing

# %% [markdown]
# We select the features to use build our prediction model based on the understanding of the data0.

# %%
new_cols = ['show_id', 'type', 'cast', 'rating', 'listed_in', 'description']

# %%
data0[new_cols].head()
# Out:
#   show_id     type                                               cast rating  \
# 0      s1  TV Show  João Miguel, Bianca Comparato, Michel Gomes, R...  TV-MA
# 1      s2    Movie  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  TV-MA
# 2      s3    Movie  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      R
# 3      s4    Movie  Elijah Wood, John C. Reilly, Jennifer Connelly...  PG-13
# 4      s5    Movie  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  PG-13
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# For the selected variables, a function is written that converts all string values to lower cases and remove spaces, in preparation for the use of cosine similarity algorithm. This is then applied to the selected columns.

# %%
def prep_d(x):
        return str.lower(x.replace(" ", ""))

# %%
data1 = data0[new_cols]
data1 = data1.astype('str')

for new_col in new_cols:
    data1.loc[:, new_col] = data1.loc[:, new_col].apply(prep_d)

data1.head(2)
# Out:
#   show_id    type                                               cast rating  \
# 0      s1  tvshow  joãomiguel,biancacomparato,michelgomes,rodolfo...  tv-ma
# 1      s2   movie  demiánbichir,héctorbonilla,oscarserrano,azalia...  tv-ma
#
#                                         listed_in  \
# 0  internationaltvshows,tvdramas,tvsci-fi&fantasy
# 1                      dramas,internationalmovies
#
#                                          description
# 0  inafuturewheretheeliteinhabitanislandparadisef...
# 1  afteradevastatingearthquakehitsmexicocity,trap...

# %% [markdown]
# We create a new feature that combines all features. this is the feature that will be used in making prediction.

# %%
data1['tags'] = data1.type + ' ' + data1.cast + ' ' + data1.rating + ' ' + data1.listed_in + ' ' + data1.description
data1.head(3)
# Out:
#   show_id    type                                               cast rating  \
# 0      s1  tvshow  joãomiguel,biancacomparato,michelgomes,rodolfo...  tv-ma
# 1      s2   movie  demiánbichir,héctorbonilla,oscarserrano,azalia...  tv-ma
# 2      s3   movie  teddchan,stellachung,henleyhii,lawrencekoh,tom...      r
#
#                                         listed_in  \
# 0  internationaltvshows,tvdramas,tvsci-fi&fantasy
# 1                      dramas,internationalmovies
# 2                horrormovies,internationalmovies
#
#                                          description  \
# 0  inafuturewheretheeliteinhabitanislandparadisef...
# 1  afteradevastatingearthquakehitsmexicocity,trap...
# 2  whenanarmyrecruitisfounddead,hisfellowsoldiers...
#
#                                                 tags
# 0  tvshow joãomiguel,biancacomparato,michelgomes,...
# 1  movie demiánbichir,héctorbonilla,oscarserrano,...
# 2  movie teddchan,stellachung,henleyhii,lawrencek...

# %% [markdown]
# ## Model Building

# %% [markdown]
# We create an index of the show_id feature to be used for reference in the model

# %%
indices = pd.Series(data1.index, index=data1['show_id'])
indices
# Out:
# show_id
# s1          0
# s2          1
# s3          2
# s4          3
# s5          4
#          ...
# s7783    7782
# s7784    7783
# s7785    7784
# s7786    7785
# s7787    7786
# Length: 7769, dtype: int64

# %% [markdown]
# We compile a cosine similarity algo

# %%
count = CountVectorizer(stop_words='english')
count_mat = count.fit_transform(data1['tags'])
cosine_sim1 = cosine_similarity(count_mat, count_mat)

# %% [markdown]
# create a function that uses the cosine similarity to recommend movies/tv shows.

# %%
result = 0
def get_suggestion(show_id, cosine_sim):
    global result    
    wid = indices[show_id]
    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[wid]))
    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    # Get the scores of the 30 most similar movies
    sim_scores = sim_scores[1:31]
    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]
    # Return the top 10 most similar movies
    result =  data.iloc[movie_indices]
    #result.reset_index(inplace = True)
    return result

# %% [markdown]
# ## Testing The Recommendation Model

# %% [markdown]
# We test the model based on content in various categories.

# %%
picked = 'International'

# %%
df = pd.DataFrame()

show_ids = ['s10', 's19', 's441']

for i in show_ids:
    get_suggestion(i, cosine_sim1)
    for i in picked:
        df = pd.concat([result[result['listed_in'].str.count(picked) > 0], df], ignore_index=True)
df.drop_duplicates(keep = 'first', inplace = True)
df.sort_values(by = 'show_id', ascending = False, inplace = True)

# %%
print("The model has recommended {} movies/tv shows.".format(df.shape[0]))
# Out:
# The model has recommended 43 movies/tv shows.

# %%
df.sort_values('release_year', ascending=[False]) #Sort recommended movies by 'release_year'
# Out:
#     show_id     type                                       title  \
# 338     s28    Movie                                      #Alive
# 8     s6463  TV Show                            The Hook Up Plan
# 4      s427  TV Show                                Almost Happy
# 347    s411    Movie                      All Good Ones Get Away
# 136   s7019  TV Show        The World's Most Extraordinary Homes
# 351   s2897    Movie                                 I Am Mother
# 141   s3290  TV Show                                   Kakegurui
# 353   s5862    Movie                                Stunt School
# 340   s3295    Movie                                   Kalel, 15
# 133   s1347  TV Show                                   Chocolate
# 3     s5185  TV Show                                   Revisions
# 350   s2184    Movie                                  First Kiss
# 344   s2035    Movie                                    Euphoria
# 5     s6188    Movie                          The Burial of Kojo
# 144   s5856  TV Show                                  Strongland
# 130   s5596    Movie  Si saben cómo me pongo ¿pá qué me invitan?
# 354   s2339    Movie                             Galih dan Ratna
# 349   s1899    Movie                                     Dushman
# 137   s3412    Movie                                  Kiss & Cry
# 7     s4752    Movie                                    Pandigai
# 6     s3842    Movie                                   Mad World
# 131    s151    Movie                      A Billion Colour Story
# 145   s6570    Movie                             The Last Shaman
# 9       s39  TV Show                         แผนร้ายนายเจ้าเล่ห์
# 346   s5329    Movie                                      Saawan
# 348   s1527  TV Show                                   Crazyhead
# 339   s4581    Movie     Offline - Das leben ist kein bonuslevel
# 135   s3898    Movie                                      Man Up
# 138   s4848    Movie                                     Phir Se
# 342    s130    Movie                                       6-5=2
# 142   s3358    Movie                                  Khoobsurat
# 134   s2566    Movie                               Hükümet Kadin
# 2     s4019  TV Show                                   Mega Food
# 0     s4737    Movie                          Pagpag: Nine Lives
# 139   s1458    Movie                                Cold Harbour
# 143   s4727  TV Show            Pablo Escobar, el patrón del mal
# 140    s275    Movie                                   Aata Pita
# 345   s5231    Movie                              Road to Sangam
# 352   s4257    Movie                                Mr. Romantic
# 343   s7388  TV Show                              Vampire Knight
# 341     s98    Movie                                 3 Deewarein
# 1      s928    Movie                                Billy Elliot
# 132   s1260    Movie                       Chadi Jawani Budhe Nu
#
#                        director  \
# 338                      Cho Il
# 8                           NaN
# 4             Hernán Guerschuny
# 347               Víctor García
# 136                         NaN
# 351               Grant Sputore
# 141                         NaN
# 353            Ali Yorgancıoğlu
# 340                    Jun Lana
# 133                         NaN
# 3                           NaN
# 350               Roy Poortmans
# 344              Valeria Golino
# 5          Sam "Blitz" Bazawule
# 144                         NaN
# 130             Fernando Ayllón
# 354              Lucky Kuswandi
# 349            Shagufta Rafique
# 137               Sean Cisterna
# 7                         Feroz
# 6                     Chun Wong
# 131  Padmakumar Narasimhamurthy
# 145                   Raz Degan
# 9                           NaN
# 346                 Farhan Alam
# 348                         NaN
# 339             Florian Schnell
# 135                  Ben Palmer
# 138    Ajay Bhuyan, Kunal Kohli
# 342                 Bharat Jain
# 142             Shashanka Ghosh
# 134             Sermiyan Midyat
# 2                           NaN
# 0                 Frasco Mortiz
# 139              Carey McKenzie
# 143                         NaN
# 140               Uttung Shelar
# 345                    Amit Rai
# 352              Ahmed Al-Badry
# 343                         NaN
# 341             Nagesh Kukunoor
# 1                Stephen Daldry
# 132                         NaN
#
#                                                   cast  \
# 338                           Yoo Ah-in, Park Shin-hye
# 8    Marc Ruchmann, Zita Hanrot, Sabrina Ouazani, J...
# 4    Sebastián Wainraich, Natalie Pérez, Santiago K...
# 347  Claire Forlani, Jake Abel, Titus Welliver, Mel...
# 136                     Piers Taylor, Caroline Quentin
# 351  Clara Rugaard, Rose Byrne, Hilary Swank, Luke ...
# 141       Minami Hamabe, Mahiro Takasugi, Aoi Morikawa
# 353  Aslı İnandık, Toygan Avanoğlu, Tuna Orhan, Can...
# 340  Elijah Canlas, Eddie Garcia, Jaclyn Jose, Gabb...
# 133  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 3    Koki Uchiyama, Mikako Komatsu, Nobunaga Shimaz...
# 350  Vajèn van den Bosch, Buddy Vedder, Leontine Bo...
# 344  Riccardo Scamarcio, Valerio Mastandrea, Isabel...
# 5    Cynthia Dankwa, Ama K. Abebrese, Joseph Otsima...
# 144                                                NaN
# 130  Ricardo Quevedo, Iván Marín, Freddy Beltrán, N...
# 354  Refal Hady, Sheryl Sheinafia, Ayu Dyah Pasha, ...
# 349  Kartar Cheema, Jashan Singh, Sakshi Gulati, Gu...
# 137  Sarah Fisher, Luke Bilyk, Chantal Kreviazuk, S...
# 7    Kreshna, Anandhi, Saravanan, Madhusudhanan, Bl...
# 6    Shawn Yue, Eric Tsang, Elaine Jin, Charmaine Fong
# 131           Dhruva Padmakumar, Gaurav Sharma, Vasuki
# 145                                      James Freeman
# 9    Chutavuth Pattarakampol, Sheranut Yusananda, N...
# 346  Karam Hussain, Arif Bahlim, Najiba Faiz, Salee...
# 8    When Parisian Elsa gets hung up on her ex, her...
# 4    Sebastián is a radio show host of modest fame,...
# 347  When a mysterious figure blackmails an adulter...
# 136  Award-winning architect Piers Taylor and actre...
# 351  Following humanity's mass extinction, a teen r...
# 141  Yumeko Jabami enrolls at Hyakkaou Private Acad...
# 353  An aspiring actress is admitted to a prestigio...
# 340  Surrounded by tensions and secrets, a teenage ...
# 133  Brought together by meaningful meals in the pa...
# 3    When Shibuya time-warps to 2388, high schooler...
# 350  A starry-eyed employee of a hot cosmetics comp...
# 344  An entrepreneur prone to partying and his estr...
# 5    When a man is left to die inside an illegal go...
# 144  From Spain's countryside to Scotland's stony t...
# 130  When four unhappy couples attend a spiritual r...
# 354  Sparks fly between the new girl at school and ...
# 349  An Indian hotel waiter forms an unlikely bond ...
# 137  Faced with a rare form of throat cancer, teen ...
# 7    Looking for a way out of his impoverished life...
# 6    A stockbroker struggling with bipolar disorder...
# 131  The curious child of idealistic interfaith par...
# 145  In a last-ditch effort to prevent suicide, a c...
# 9    When two brothers fall for two sisters, they q...
# 346  Outcast from society and left to die in the wi...
# 348  Bowling alley worker Amy and nonconformist Raq...
# 339  Competitive gamer Jan finds his life thrown fo...
# 135  A single woman seizes an opportunity when, whi...
# 138  The paths of a man and a woman, who have both ...
# 342  Six friends decide to undertake a grueling mou...
# 142  A free-spirited doctor is hired to assist an i...
# 134  When an uneducated mother of eight suddenly be...
# 2    Visiting the busiest kitchens in the world, th...
# 0    After ignoring superstitions, a group of teena...
# 139  When a war breaks out between competing gangs ...
# 143  From his days as a petty thief to becoming hea...
# 140  A municipal clerk with literary ambitions stal...
# 345  As communal violence erupts in his neighborhoo...
# 352  When a carefree man is left with his uncle's f...
# 343  At Cross Academy, two student disciplinary com...
# 341  A reporter interviews three convicts on death ...
# 1    When a boy trades boxing school for ballet les...
# 132  After reaching his 40th birthday, an egotistic...

# %%
len(df) == len(df[df['listed_in'].str.contains(picked)]) #Check if each row has the 'international' category
# Out:
# True

# %% [markdown]
# Let's test with a different category from a different feature, say 'TV-MA' from the 'rating' feature.

# %%
picked1 = result.iloc[1,-4]
picked1
# Out:
# 'TV-MA'

# %%
df = pd.DataFrame()

show_ids = ['s10', 's19', 's441']

for i in show_ids:
    get_suggestion(i, cosine_sim1)
    for i in picked1:
        df = pd.concat([result[result['rating'].str.count(picked1) > 0], df], ignore_index=True)
df.drop_duplicates(keep = 'first', inplace = True)
df.sort_values(by = 'show_id', ascending = False, inplace = True)

# %%
print("The model has recommended {} movies/tv shows.".format(df.shape[0]))
# Out:
# The model has recommended 34 movies/tv shows.

# %%
df.sort_values('release_year', ascending=[False])  #Sort recommended movies by 'release_year'
# Out:
#     show_id     type                                       title  \
# 116   s6702  TV Show                      The Netflix Afterparty
# 2     s4054  TV Show                                     Messiah
# 3      s427  TV Show                                Almost Happy
# 110   s1496  TV Show                        Cooked with Cannabis
# 8     s6463  TV Show                            The Hook Up Plan
# 105     s28    Movie                                      #Alive
# 111   s2652  TV Show                                     Haunted
# 59    s3290  TV Show                                   Kakegurui
# 107   s3295    Movie                                   Kalel, 15
# 112    s411    Movie                      All Good Ones Get Away
# 0     s1183    Movie                   Calum von Moger: Unbroken
# 115   s5973  TV Show                           Tales of the City
# 9     s5605    Movie                                    Silencer
# 4     s6685  TV Show                         The Mortified Guide
# 7     s4983    Movie                              Professor Mack
# 53    s5596    Movie  Si saben cómo me pongo ¿pá qué me invitan?
# 56    s3412    Movie                                  Kiss & Cry
# 55     s579  TV Show                Ari Shaffir: Double Negative
# 58    s3100    Movie                    Jack Whitehall: At Large
# 6     s4752    Movie                                    Pandigai
# 50    s7532    Movie                          Welcome to Willits
# 51    s4797    Movie                 Patton Oswalt: Annihilation
# 114   s4393    Movie                                       Nails
# 5     s3842    Movie                                   Mad World
# 113   s1527  TV Show                                   Crazyhead
# 106   s4581    Movie     Offline - Das leben ist kein bonuslevel
# 117   s1479    Movie                                  Compulsion
# 109    s130    Movie                                       6-5=2
# 54    s2566    Movie                               Hükümet Kadin
# 57    s1458    Movie                                Cold Harbour
# 60    s4727  TV Show            Pablo Escobar, el patrón del mal
# 1     s2023    Movie                Eric ldle's What About Dick?
# 52    s3326    Movie   Katt Williams: The Pimp Chronicles: Pt. 1
# 108     s98    Movie                                 3 Deewarein
#
#                      director  \
# 116                       NaN
# 2                         NaN
# 3           Hernán Guerschuny
# 110                       NaN
# 8                         NaN
# 105                    Cho Il
# 111                       NaN
# 59                        NaN
# 107                  Jun Lana
# 112             Víctor García
# 0                  Vlad Yudin
# 115                       NaN
# 9        Timothy Woodward Jr.
# 4                         NaN
# 7           Christopher Nolen
# 53            Fernando Ayllón
# 56              Sean Cisterna
# 55                Eric Abrams
# 58                Brian Klein
# 6                       Feroz
# 50                Trevor Ryan
# 51          Bobcat Goldthwait
# 114             Dennis Bartok
# 5                   Chun Wong
# 113                       NaN
# 106           Florian Schnell
# 117            Craig Goodwill
# 109               Bharat Jain
# 54            Sermiyan Midyat
# 57             Carey McKenzie
# 60                        NaN
# 1    Eric Idle, Aubrey Powell
# 52                Gary Binkow
# 108           Nagesh Kukunoor
#
#                                                   cast  \
# 116       David Spade, London Hughes, Fortune Feimster
# 2    Michelle Monaghan, Mehdi Dehbi, John Ortiz, To...
# 3    Sebastián Wainraich, Natalie Pérez, Santiago K...
# 110                              Kelis, Leather Storrs
# 8    Marc Ruchmann, Zita Hanrot, Sabrina Ouazani, J...
# 105                           Yoo Ah-in, Park Shin-hye
# 111                                                NaN
# 59        Minami Hamabe, Mahiro Takasugi, Aoi Morikawa
# 107  Elijah Canlas, Eddie Garcia, Jaclyn Jose, Gabb...
# 112  Claire Forlani, Jake Abel, Titus Welliver, Mel...
# 0                                      Calum Von Moger
# 115  Laura Linney, Ellen Page, Olympia Dukakis, Pau...
# 9    Johnny Messner, Danny Trejo, Tito Ortiz, Chuck...
# 4                                                  NaN
# 7    Lisa Wu, Timon Kyle Durrett, Robert Christophe...
# 53   Ricardo Quevedo, Iván Marín, Freddy Beltrán, N...
# 56   Sarah Fisher, Luke Bilyk, Chantal Kreviazuk, S...
# 55                                         Ari Shaffir
#                                              listed_in  \
# 116          Stand-Up Comedy & Talk Shows, TV Comedies
# 2                              TV Dramas, TV Thrillers
# 3    International TV Shows, Spanish-Language TV Sh...
# 110                                         Reality TV
# 8    International TV Shows, Romantic TV Shows, TV ...
# 105     Horror Movies, International Movies, Thrillers
# 111                Reality TV, TV Horror, TV Thrillers
# 59     International TV Shows, TV Dramas, TV Thrillers
# 107   Dramas, Independent Movies, International Movies
# 112                    International Movies, Thrillers
# 0                         Documentaries, Sports Movies
# 115                                          TV Dramas
# 9               Action & Adventure, Independent Movies
# 4                                           Docuseries
# 7                            Comedies, Romantic Movies
# 53                      Comedies, International Movies
# 56       Dramas, International Movies, Romantic Movies
# 55                        Stand-Up Comedy & Talk Shows
# 58                                     Stand-Up Comedy
# 6     Action & Adventure, Dramas, International Movies
# 50         Comedies, Horror Movies, Independent Movies
# 51                                     Stand-Up Comedy
# 114                                      Horror Movies
# 5                         Dramas, International Movies
# 113  British TV Shows, International TV Shows, TV C...
# 106  Action & Adventure, Comedies, International Mo...
# 117                                  Dramas, Thrillers
# 109     Horror Movies, International Movies, Thrillers
# 54                      Comedies, International Movies
# 57    Action & Adventure, Dramas, International Movies
# 60   Crime TV Shows, International TV Shows, Spanis...
# 1                           Comedies, Music & Musicals
# 52                                     Stand-Up Comedy
# 108            Dramas, International Movies, Thrillers
#
#                                            description
# 116  Hosts David Spade, Fortune Feimster and London...
# 2    A wary CIA officer investigates a charismatic ...
# 3    Sebastián is a radio show host of modest fame,...
# 110  Chefs compete to get the hosts and special gue...
# 8    When Parisian Elsa gets hung up on her ex, her...
# 105  As a grisly virus rampages a city, a lone man ...
# 111  Real people sit down with friends and family t...
# 59   Yumeko Jabami enrolls at Hyakkaou Private Acad...
# 107  Surrounded by tensions and secrets, a teenage ...
# 112  When a mysterious figure blackmails an adulter...
# 0    Bodybuilder and two-time Mr. Universe, Calum v...
# 115  Returning to San Francisco after a long absenc...
# 9    When a drug lord kidnaps his girlfriend’s daug...
# 4    Brave people get onstage to read hilarious and...
# 7    When a confident college professor is courted ...
# 53   When four unhappy couples attend a spiritual r...
# 56   Faced with a rare form of throat cancer, teen ...
# 55   Wry yet thoughtful, comedian Ari Shaffir bring...
# 58   Comedian Jack Whitehall takes the stage to tel...
# 6    Looking for a way out of his impoverished life...
# 50   A marijuana farmer's extraterrestrial paranoia...
# 51   By turns scathing and candid, Patton Oswalt re...
# 114  Recently paralyzed in a devastating car accide...
# 5    A stockbroker struggling with bipolar disorder...
# 113  Bowling alley worker Amy and nonconformist Raq...
# 106  Competitive gamer Jan finds his life thrown fo...
# 117  Lured to a majestic, remote villa by an old lo...
# 109  Six friends decide to undertake a grueling mou...
# 54   When an uneducated mother of eight suddenly be...
# 57   When a war breaks out between competing gangs ...
# 60   From his days as a petty thief to becoming hea...
# 1    In a madcap stage play from Monty Python icon ...
# 52   In this 2006 show, comic Katt Williams uses hi...
# 108  A reporter interviews three convicts on death ...

# %%
len(df) == len(df[df['rating'].str.contains(picked1)]) #Check if each row has the 'TV-MA' category
# Out:
# True
